# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.udemy.com/course/framestorm-your-way-to-success-in-business/?couponCode=LEADERSALE24A'

# %%
req = requests.get(url)
soup = BeautifulSoup(req.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
#  <head>
#   <title>
#    Master Your Mindset &amp; Brain: Framestorm® Your Way to Success | Udemy
#   </title>
#   <script nonce="hN2GlNN6tKRA73CNsBXggDMFScuAyP3Qs6tTUtzyMnE=" type="text/javascript">
#    // Note: must be called before google tag manager is initialized in OptanonWrapper()
#         if (typeof window.dataLayer == 'undefined') {
#             window.dataLayer = window.dataLayer || [];
#         }
#
#         function callGtag() {
#             window.dataLayer.push(arguments);
#         }
#
#         var GRANTED = 'granted';
#         var DENIED = 'denied';
#
#         window.optOutConsent = {
#             ad_storage: GRANTED,
#             analytics_storage: GRANTED,
#             functionality_storage: GRANTED,
#             personalization_storage: GRANTED,
#             security_storage: GRANTED
#         }
#
#         window.optInConsent = {
#             ad_storage: DENIED,
#             analytics_storage: DENIED,
# ...
